# %%
age = int(input('請輸入age:'))
if age >= 18:
    print("可以考駕照!")
    print("===========")
else:
    print("不可以考駕照!")
    print("==============")

print("應用程式結束")
# Out:
# 可以考駕照!
# ...
# 應用程式結束

# %% [markdown]
# 1
